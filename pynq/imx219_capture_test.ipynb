# %%
from imx219_capture import CaptureConfig, capture_and_show

config = CaptureConfig(
    bit_file="design_1.bit",
    hwh_file="design_1.hwh",
    test_pattern=0x0000,   # 実画像
)

frames, report = capture_and_show(config)
